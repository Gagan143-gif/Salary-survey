# %% [markdown]
# <a href="https://colab.research.google.com/github/Gagan143-gif/Gagan143-gif/blob/main/Salary_survey.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns #visualisation
import matplotlib.pyplot as plt #visualisation

# %%
# Access a file from Google Drive
file_path = '/Salary_Survey.csv'
df = pd.read_csv(file_path)

# %%
df.head()
# Out:
#             Timestamp How old are you?  What industry do you work in?  \
# 0  4/27/2021 11:02:10            25-34   Education (Higher Education)
# 1  4/27/2021 11:02:22            25-34              Computing or Tech
# 2  4/27/2021 11:02:38            25-34  Accounting, Banking & Finance
# 3  4/27/2021 11:02:41            25-34                     Nonprofits
# 4  4/27/2021 11:02:42            25-34  Accounting, Banking & Finance
#
#                                   Job title  \
# 0        Research and Instruction Librarian
# 1  Change & Internal Communications Manager
# 2                      Marketing Specialist
# 3                           Program Manager
# 4                        Accounting Manager
#
#   If your job title needs additional context, please clarify here:  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# ...

# %%
df.tail()
# Out:
#       Timestamp How old are you? What industry do you work in? Job title  \
# 28173       NaN              NaN                           NaN       NaN
# 28174       NaN              NaN                           NaN       NaN
# 28175       NaN              NaN                           NaN       NaN
# 28176       NaN              NaN                           NaN       NaN
# 28177       NaN              NaN                           NaN       NaN
#
#       If your job title needs additional context, please clarify here:  \
# 28173                                                NaN
# 28174                                                NaN
# 28175                                                NaN
# 28176                                                NaN
# 28177                                                NaN
#
# ...

# %%
df.dtypes
# Out:
# Timestamp                                                                                                                                                                                                                                object
# How old are you?                                                                                                                                                                                                                         object
# What industry do you work in?                                                                                                                                                                                                            object
# Job title                                                                                                                                                                                                                                object
# ...

# %%
# Dropping irrelevant columns
df = df.drop(['Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22'], axis=1)
df.head()
# Out:
#             Timestamp How old are you?  What industry do you work in?  \
# 0  4/27/2021 11:02:10            25-34   Education (Higher Education)
# 1  4/27/2021 11:02:22            25-34              Computing or Tech
# 2  4/27/2021 11:02:38            25-34  Accounting, Banking & Finance
# 3  4/27/2021 11:02:41            25-34                     Nonprofits
# 4  4/27/2021 11:02:42            25-34  Accounting, Banking & Finance
#
#                                   Job title  \
# 0        Research and Instruction Librarian
# 1  Change & Internal Communications Manager
# 2                      Marketing Specialist
# 3                           Program Manager
# 4                        Accounting Manager
#
#   If your job title needs additional context, please clarify here:  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# ...

# %%
# Renaming the column names
df = df.rename(columns={"How old are you?":"Age","What industry do you work in?":"Work field","What city do you work in?":"City"})
df.head()
# Out:
#             Timestamp    Age                     Work field  \
# 0  4/27/2021 11:02:10  25-34   Education (Higher Education)
# 1  4/27/2021 11:02:22  25-34              Computing or Tech
# 2  4/27/2021 11:02:38  25-34  Accounting, Banking & Finance
# 3  4/27/2021 11:02:41  25-34                     Nonprofits
# 4  4/27/2021 11:02:42  25-34  Accounting, Banking & Finance
#
#                                   Job title  \
# 0        Research and Instruction Librarian
# 1  Change & Internal Communications Manager
# 2                      Marketing Specialist
# 3                           Program Manager
# 4                        Accounting Manager
#
#   If your job title needs additional context, please clarify here:  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# ...

# %%
# Total number of rows and columns
df.shape
# Out:
# (28178, 17)

# %%
# Rows containing duplicate data
duplicate_rows_df = df[df.duplicated()]

# %%
print("number of duplicate rows: ", duplicate_rows_df.shape)
# Out:
# number of duplicate rows:  (92, 17)

# %%
# Used to count the number of rows before removing the data
df.count()
# Out:
# Timestamp                                                                                                                                                                                                                               28085
# Age                                                                                                                                                                                                                                     28085
# Work field                                                                                                                                                                                                                              28011
# Job title                                                                                                                                                                                                                               28084
# ...

# %%
#Dropping the missing or null values
# Finding the null values.
print(df.isnull().sum())
# Out:
# Timestamp                                                                                                                                                                                                                                  93
# Age                                                                                                                                                                                                                                        93
# Work field                                                                                                                                                                                                                                167
# Job title                                                                                                                                                                                                                                  94
# ...

# %%
# Dropping the missing values.
df = df.dropna()
df.count()
# Out:
# Timestamp                                                                                                                                                                                                                               5
# Age                                                                                                                                                                                                                                     5
# Work field                                                                                                                                                                                                                              5
# Job title                                                                                                                                                                                                                               5
# ...
